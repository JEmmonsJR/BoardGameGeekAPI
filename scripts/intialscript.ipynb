# %%
#standard imports
import numpy as np
import pandas as pd

# %% [markdown]
# Importing Data

# %%
bg_info = pd.read_csv("../data/bg_info.csv")
bg_artists = pd.read_csv("../data/bg_artists.csv")
bg_designers = pd.read_csv("../data/bg_designers.csv")
bg_publishers = pd.read_csv("../data/bg_publishers.csv")

# %%
bg_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25339 entries, 0 to 25338
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          25339 non-null  object
#  1   Geek Rating    25339 non-null  float64
#  2   Avg rating     25339 non-null  float64
#  3   Num of voters  25339 non-null  int64
#  4   Price          4150 non-null   float64
#  5   Year           25113 non-null  float64
#  6   Complexity     25339 non-null  float64
#  7   Min players    25298 non-null  float64
#  8   Max players    25298 non-null  float64
#  9   Min time       24513 non-null  float64
#  10  Max time       24513 non-null  float64
#  11  Age            23841 non-null  float64
#  12  Type 1         13327 non-null  object
#  13  Type 2         1828 non-null   object
# dtypes: float64(10), int64(1), object(3)
# memory usage: 2.7+ MB

# %%
bg_artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25609 entries, 0 to 25608
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     25609 non-null  object
#  1   Artist 1  18855 non-null  object
#  2   Artist 2  7074 non-null   object
#  3   Artist 3  3076 non-null   object
#  4   Artist 4  1513 non-null   object
#  5   Artist 5  334 non-null    object
# dtypes: object(6)
# memory usage: 1.2+ MB

# %%
bg_designers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25528 entries, 0 to 25527
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       25528 non-null  object
#  1   Designer 1  24660 non-null  object
#  2   Designer 2  6808 non-null   object
#  3   Designer 3  1684 non-null   object
#  4   Designer 4  486 non-null    object
#  5   Designer 5  91 non-null     object
# dtypes: object(6)
# memory usage: 1.2+ MB

# %%
bg_publishers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25302 entries, 0 to 25301
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        25302 non-null  object
#  1   Publisher 1  25286 non-null  object
#  2   Publisher 2  7566 non-null   object
#  3   Publisher 3  3262 non-null   object
#  4   Publisher 4  1828 non-null   object
#  5   Publisher 5  373 non-null    object
# dtypes: object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# BG Info Overview

# %%
bg_info
# Out:
#                                    Title  Geek Rating  Avg rating  \
# 0                      Brass: Birmingham        8.421        8.61
# 1              Pandemic Legacy: Season 1        8.386        8.53
# 2                             Gloomhaven        8.374        8.61
# 3                               Ark Nova        8.321        8.53
# 4      Twilight Imperium: Fourth Edition        8.242        8.61
# ...                                  ...          ...         ...
# 25334                      Stupid Deaths        5.352        4.47
# 25335                         Stay Alive        5.352        5.05
# 25336                 Gazdálkodj Okosan!        5.351        4.54
# 25337                           Pie Face        5.348        4.80
# 25338                          Redshirts        5.348        4.60
#
#        Num of voters   Price    Year  Complexity  Min players  Max players  \
# 0              41991   84.99  2018.0        3.89          2.0          4.0
# ...

# %%
bg_info.describe()
# Out:
#         Geek Rating    Avg rating  Num of voters        Price         Year  \
# count  25339.000000  25339.000000    25339.00000  4150.000000  25113.00000
# mean       5.677981      6.467281      914.57816    51.985364   2006.07291
# std        0.351667      0.917515     4039.40888    56.365385     84.41056
# min        5.348000      1.180000       30.00000     1.990000  -3500.00000
# 25%        5.510000      5.890000       56.00000    23.292500   2004.00000
# 50%        5.541000      6.490000      123.00000    37.305000   2013.00000
# 75%        5.660000      7.090000      398.00000    59.950000   2018.00000
# max        8.421000      9.760000   123256.00000   999.990000   2025.00000
#
#          Complexity   Min players   Max players      Min time      Max time  \
# count  25339.000000  25298.000000  25298.000000  24513.000000  24513.000000
# mean       1.959908      1.977152      5.920982     61.127687     96.594052
# ...

# %% [markdown]
# BG Artist Overview

# %%
bg_artists
# Out:
#                                         Title          Artist 1  \
# 0                           Brass: Birmingham       Gavan Brown
# 1                   Pandemic Legacy: Season 1   Chris Quilliams
# 2                                  Gloomhaven  Alexandr Elichev
# 3                                    Ark Nova    Steffen Bieker
# 4           Twilight Imperium: Fourth Edition   Scott Schomburg
# ...                                       ...               ...
# 25604             The Walking Dead Board Game       Larry Renac
# 25605           Lord of the Rings: The Search         John Howe
# 25606                             Bondespelet     Bildgården AB
# 25607  Star Wars: Escape from Death Star Game    Lucasfilm Ltd.
# 25608                                     UNO    Shepard Fairey
#
#                Artist 2              Artist 3          Artist 4     Artist 5
# 0         Lina Cossette          David Forest  Damien Mammoliti  Matt Tolman
# ...

# %%
bg_artists.describe()
# Out:
#              Title      Artist 1            Artist 2            Artist 3  \
# count        25609         18855                7074                3076
# unique       25193          6952                3566                1925
# top     Robin Hood  (Uncredited)  Rodger B. MacGowan  Rodger B. MacGowan
# freq             6           356                 112                  61
#
#               Artist 4        Artist 5
# count             1513             334
# unique            1120             272
# top     Mark Simonitch  Mark Simonitch
# freq                37              15

# %% [markdown]
# BG Designers Overview

# %%
bg_designers
# Out:
#                                    Title           Designer 1  \
# 0                      Brass: Birmingham          Gavan Brown
# 1              Pandemic Legacy: Season 1           Rob Daviau
# 2                             Gloomhaven       Isaac Childres
# 3                               Ark Nova        Mathias Wigge
# 4      Twilight Imperium: Fourth Edition        Dane Beltrami
# ...                                  ...                  ...
# 25523                     Scrabble Slam!        Joe Wetherell
# 25524                          SpellBook  Phil Walker-Harding
# 25525           Before the Guests Arrive               Saashi
# 25526           Star Trek: Away Missions        Andrew Haught
# 25527                  For One: Galaktix        Reiner Knizia
#
#             Designer 2             Designer 3 Designer 4 Designer 5
# 0          Matt Tolman         Martin Wallace        NaN        NaN
# 1         Matt Leacock                    NaN        NaN        NaN
# ...

# %%
bg_designers.describe()
# Out:
#              Title    Designer 1    Designer 2        Designer 3  \
# count        25528         24660          6808              1684
# unique       25110          8344          3457              1103
# top     Robin Hood  (Uncredited)  Markus Brand  Michael S. Steer
# freq             6          1523            77                25
#
#            Designer 4     Designer 5
# count             486             91
# unique            369             73
# top     Mike Selinker  Antonio Tinto
# freq                8              8

# %% [markdown]
# BG Publishers Overview

# %%
bg_publishers
# Out:
#                                               Title  \
# 0                                 Brass: Birmingham
# 1                         Pandemic Legacy: Season 1
# 2                                        Gloomhaven
# 3                                          Ark Nova
# 4                 Twilight Imperium: Fourth Edition
# ...                                             ...
# 25297                                       Skworms
# 25298                              Knightmare Chess
# 25299  Die Siedler von Catan: Historische Szenarien
# 25300                                    Looney Leo
# 25301                              Catan: Seafarers
#
#                      Publisher 1  Publisher 2 Publisher 3  \
# 0                         Roxley          NaN         NaN
# 1                    Z-Man Games          NaN         NaN
# 2              Cephalofair Games          NaN         NaN
# 3               Feuerland Spiele          NaN         NaN
# ...

# %%
bg_publishers.describe()
# Out:
#              Title       Publisher 1      Publisher 2      Publisher 3  \
# count        25302             25286             7566             3262
# unique       24838              4480             2181             1199
# top     Robin Hood  (Self-Published)  Parker Brothers  Parker Brothers
# freq             6               649              145               78
#
#            Publisher 4             Publisher 5
# count             1828                     373
# unique             767                     213
# top     Milton Bradley  Swan Panasia Co., Ltd.
# freq                40                      11
